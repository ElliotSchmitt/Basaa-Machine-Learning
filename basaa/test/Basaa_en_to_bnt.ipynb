# %% [markdown]
# <a href="https://colab.research.google.com/github/JacobSchmitt/Basaa-Machine-Learning/blob/main/basaa/test/Basaa_en_to_bnt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !wget https://raw.githubusercontent.com/JacobSchmitt/Basaa-Machine-Learning/main/basaa/data/train.tsv 
# !wget https://raw.githubusercontent.com/JacobSchmitt/Basaa-Machine-Learning/main/basaa/data/dev.tsv 
# !wget -P '/content/baseline' https://raw.githubusercontent.com/JacobSchmitt/Basaa-Machine-Learning/main/basaa/baseline/convert.py
# !wget -P '/content/baseline' https://raw.githubusercontent.com/JacobSchmitt/Basaa-Machine-Learning/main/basaa/baseline/Makefile
# !wget https://raw.githubusercontent.com/JacobSchmitt/Basaa-Machine-Learning/main/basaa/evaluate.py

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-898bd85a-525a-44a8-9837-184d2c12aa1a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-898bd85a-525a-44a8-9837-184d2c12aa1a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving corr_dev.tsv to corr_dev.tsv
# Saving corr_train.tsv to corr_train.tsv

# %%
# %%capture
# !pip install simpletransformers

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 1000)
train_df = pd.read_csv('corr_train.tsv', sep ='\t', names = ['input_text', 'target_text']).astype(str)
eval_df = pd.read_csv('corr_dev.tsv', sep ='\t', names = ['input_text', 'target_text']).astype(str)

train_df["prefix"] = ""
eval_df["prefix"] = ""

# %%
import logging
from simpletransformers.seq2seq import Seq2SeqModel


logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

# %%
# Check that we have a GPU
# !nvidia-smi
# Out:
# Wed Apr  7 06:18:38 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Check that PyTorch sees it
import torch
torch.cuda.is_available()
# Out:
# True

# %%
model_args = {
"preprocess_input_data": True,
"overwrite_output_dir": True,
"max_seq_length": 75,
"train_batch_size": 20,
"num_train_epochs": 12,
"save_eval_checkpoints": False,
"save_model_every_epoch": False,
# "silent": True,
"evaluate_generated_text": True,
"evaluate_during_training": True,
"evaluate_during_training_verbose": True,
"use_multiprocessing": True,
"save_best_model": True,
"use_multiprocessed_decoding": True,
'no_cache': True,
# 'max_length': 512,
'fp16': False
}

model = Seq2SeqModel(encoder_decoder_type = "marian", encoder_decoder_name= 'Helsinki-NLP/opus-mt-en-bnt', args=model_args)
# Out:
# INFO:filelock:Lock 140051238608720 acquired on /root/.cache/huggingface/transformers/8f5be1f38e4ed127fc571c9bd85bbb012a8b1135fd7d834594bdc1c7752468a5.9a650f69ece3b22e149f059b7c8c7d2aa10c2156dca540bc2051599512de9bb2.lock
# Downloading:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# INFO:filelock:Lock 140051238608720 released on /root/.cache/huggingface/transformers/8f5be1f38e4ed127fc571c9bd85bbb012a8b1135fd7d834594bdc1c7752468a5.9a650f69ece3b22e149f059b7c8c7d2aa10c2156dca540bc2051599512de9bb2.lock
# INFO:filelock:Lock 140048794722576 acquired on /root/.cache/huggingface/transformers/a80169ab83366f2cebc8406a8ca7c1790b85d03afcce7d3f21ebdb916382f971.3951355d759a13ed2787328928aa9ca06b98a6a542ca68913b5e4f8912c90ad6.lock
# Downloading:   0%|          | 0.00/305M [00:00<?, ?B/s]
# INFO:filelock:Lock 140048794722576 released on /root/.cache/huggingface/transformers/a80169ab83366f2cebc8406a8ca7c1790b85d03afcce7d3f21ebdb916382f971.3951355d759a13ed2787328928aa9ca06b98a6a542ca68913b5e4f8912c90ad6.lock
# INFO:filelock:Lock 140048775646352 acquired on /root/.cache/huggingface/transformers/0c1e42221cc8031416ce87a05ccf344f62144dab787989bb7823f811f4d91506.618c10d2da0d6758c48801b7a39879fd76852ae14d4cbfc2ab98521b8ffcfafc.lock
# Downloading:   0%|          | 0.00/819k [00:00<?, ?B/s]
# INFO:filelock:Lock 140048775646352 released on /root/.cache/huggingface/transformers/0c1e42221cc8031416ce87a05ccf344f62144dab787989bb7823f811f4d91506.618c10d2da0d6758c48801b7a39879fd76852ae14d4cbfc2ab98521b8ffcfafc.lock
# INFO:filelock:Lock 140048632674512 acquired on /root/.cache/huggingface/transformers/b9b7cc189d93cf23067398c44ece592dd38434dd8f4a66222f9d4e2db7629884.055f7a9876aed69e1f1519dfa7d9acc73f6d083890856cdda3f987554e6f144d.lock
# Downloading:   0%|          | 0.00/790k [00:00<?, ?B/s]
# INFO:filelock:Lock 140048632674512 released on /root/.cache/huggingface/transformers/b9b7cc189d93cf23067398c44ece592dd38434dd8f4a66222f9d4e2db7629884.055f7a9876aed69e1f1519dfa7d9acc73f6d083890856cdda3f987554e6f144d.lock
# INFO:filelock:Lock 140048633774800 acquired on /root/.cache/huggingface/transformers/71fa90e13d43c33b4ebd2650a51574a0365c3cafefc90e5a8bfe4f2fc74f33b1.7b3344f2d1a08bea342822520ff757928c98e27fdb26954ae8a142b5fd75d1f1.lock
# Downloading:   0%|          | 0.00/1.35M [00:00<?, ?B/s]
# INFO:filelock:Lock 140048633774800 released on /root/.cache/huggingface/transformers/71fa90e13d43c33b4ebd2650a51574a0365c3cafefc90e5a8bfe4f2fc74f33b1.7b3344f2d1a08bea342822520ff757928c98e27fdb26954ae8a142b5fd75d1f1.lock
# INFO:filelock:Lock 140048632672592 acquired on /root/.cache/huggingface/transformers/d0991ade82cc084c791e925003c2114c7e0129cfecfc442e8ae19941ffae967e.8c87267fa915d12168203a440638793079495182c0fecf7585b135de3d47323e.lock
# Downloading:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# INFO:filelock:Lock 140048632672592 released on /root/.cache/huggingface/transformers/d0991ade82cc084c791e925003c2114c7e0129cfecfc442e8ae19941ffae967e.8c87267fa915d12168203a440638793079495182c0fecf7585b135de3d47323e.lock

# %%
model.train_model(train_df, eval_data=eval_df)
# Out:
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model: Training started
# Epoch:   0%|          | 0/12 [00:00<?, ?it/s]
# Running Epoch 0 of 12:   0%|          | 0/500 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating outputs:   0%|          | 0/1250 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3226: FutureWarning: `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of 🤗 Transformers. Use the regular `__call__` method to prepare your inputs and the tokenizer under the `with_target_tokenizer` context manager to prepare your targets. See the documentation of your specific tokenizer for more details
#   FutureWarning,
# Decoding outputs:   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:{'eval_loss': 0.6846949360024184}
# INFO:simpletransformers.seq2seq.seq2seq_model:Saving model into outputs/best_model
# Running Epoch 1 of 12:   0%|          | 0/500 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating outputs:   0%|          | 0/1250 [00:00<?, ?it/s]
# Decoding outputs:   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:{'eval_loss': 0.420489880823344}
# INFO:simpletransformers.seq2seq.seq2seq_model:Saving model into outputs/best_model
# Running Epoch 2 of 12:   0%|          | 0/500 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating outputs:   0%|          | 0/1250 [00:00<?, ?it/s]
# Decoding outputs:   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:{'eval_loss': 0.330579832706321}
# INFO:simpletransformers.seq2seq.seq2seq_model:Saving model into outputs/best_model
# Running Epoch 3 of 12:   0%|          | 0/500 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:Saving model into outputs/checkpoint-2000
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating outputs:   0%|          | 0/1250 [00:00<?, ?it/s]
# Decoding outputs:   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:{'eval_loss': 0.2783144548747223}
# INFO:simpletransformers.seq2seq.seq2seq_model:Saving model into outputs/best_model
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating outputs:   0%|          | 0/1250 [00:00<?, ?it/s]
# Decoding outputs:   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:{'eval_loss': 0.2783144548747223}
# Running Epoch 4 of 12:   0%|          | 0/500 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating outputs:   0%|          | 0/1250 [00:00<?, ?it/s]
# Decoding outputs:   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:{'eval_loss': 0.2305477600814309}
# INFO:simpletransformers.seq2seq.seq2seq_model:Saving model into outputs/best_model
# Running Epoch 5 of 12:   0%|          | 0/500 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating outputs:   0%|          | 0/1250 [00:00<?, ?it/s]
# Decoding outputs:   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:{'eval_loss': 0.19698409972260705}
# INFO:simpletransformers.seq2seq.seq2seq_model:Saving model into outputs/best_model
# Running Epoch 6 of 12:   0%|          | 0/500 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating outputs:   0%|          | 0/1250 [00:00<?, ?it/s]
# Decoding outputs:   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:{'eval_loss': 0.16993406690000556}
# INFO:simpletransformers.seq2seq.seq2seq_model:Saving model into outputs/best_model
# Running Epoch 7 of 12:   0%|          | 0/500 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:Saving model into outputs/checkpoint-4000
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating outputs:   0%|          | 0/1250 [00:00<?, ?it/s]
# Decoding outputs:   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:{'eval_loss': 0.15238553288385737}
# INFO:simpletransformers.seq2seq.seq2seq_model:Saving model into outputs/best_model
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating outputs:   0%|          | 0/1250 [00:00<?, ?it/s]
# Decoding outputs:   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:{'eval_loss': 0.15238553288385737}
# Running Epoch 8 of 12:   0%|          | 0/500 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating outputs:   0%|          | 0/1250 [00:00<?, ?it/s]
# Decoding outputs:   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:{'eval_loss': 0.1309406177681405}
# INFO:simpletransformers.seq2seq.seq2seq_model:Saving model into outputs/best_model
# Running Epoch 9 of 12:   0%|          | 0/500 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating outputs:   0%|          | 0/1250 [00:00<?, ?it/s]
# Decoding outputs:   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:{'eval_loss': 0.12096207309871679}
# INFO:simpletransformers.seq2seq.seq2seq_model:Saving model into outputs/best_model
# Running Epoch 10 of 12:   0%|          | 0/500 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating outputs:   0%|          | 0/1250 [00:00<?, ?it/s]
# Decoding outputs:   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:{'eval_loss': 0.11235179507490248}
# INFO:simpletransformers.seq2seq.seq2seq_model:Saving model into outputs/best_model
# Running Epoch 11 of 12:   0%|          | 0/500 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:Saving model into outputs/checkpoint-6000
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating outputs:   0%|          | 0/1250 [00:00<?, ?it/s]
# Decoding outputs:   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:{'eval_loss': 0.10878838945738971}
# INFO:simpletransformers.seq2seq.seq2seq_model:Saving model into outputs/best_model
# INFO:simpletransformers.seq2seq.seq2seq_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating outputs:   0%|          | 0/1250 [00:00<?, ?it/s]
# Decoding outputs:   0%|          | 0/10000 [00:00<?, ?it/s]
# INFO:simpletransformers.seq2seq.seq2seq_model:{'eval_loss': 0.10878838945738971}
# INFO:simpletransformers.seq2seq.seq2seq_model:Saving model into outputs/
# INFO:simpletransformers.seq2seq.seq2seq_model: Training of Helsinki-NLP/opus-mt-en-bnt model complete. Saved to outputs/.
# (6000,
#  {'eval_loss': [0.6846949360024184,
#    0.420489880823344,
#    0.330579832706321,
#    0.2783144548747223,
#    0.2783144548747223,
#    0.2305477600814309,
#    0.19698409972260705,
#    0.16993406690000556,
#    0.15238553288385737,
#    0.15238553288385737,
#    0.1309406177681405,
#    0.12096207309871679,
#    0.11235179507490248,
#    0.10878838945738971,
#    0.10878838945738971],
#   'global_step': [500,
#    1000,
#    1500,
#    2000,
#    2000,
#    2500,
#    3000,
#    3500,
#    4000,
#    4000,
#    4500,
#    5000,
#    5500,
#    6000,
#    6000],
#   'train_loss': [0.7772941589355469,
#    0.5508484840393066,
#    0.6091024875640869,
#    0.5480455756187439,
#    0.5480455756187439,
#    0.33764466643333435,
#    0.30936047434806824,
#    0.28006014227867126,
#    0.2735682725906372,
#    0.2735682725906372,
#    0.1878405660390854,
#    0.16453051567077637,
#    0.239008828997612,
#    0.14453810453414917,
#    0.14453810453414917]})

# %%
import logging
import pandas as pd

logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)


model_args = {
'max_length': 512,
'length_penalty' : 1,
'num_beams' : 10}

model = Seq2SeqModel(encoder_decoder_type = "marian", encoder_decoder_name= 'outputs/best_model', args=model_args)

# %%
sinhala_truth = eval_df['target_text'].tolist()

# %%
sinhala_preds = model.predict(eval_df['input_text'].tolist())
# Out:
# Generating outputs:   0%|          | 0/1250 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3226: FutureWarning: `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of 🤗 Transformers. Use the regular `__call__` method to prepare your inputs and the tokenizer under the `with_target_tokenizer` context manager to prepare your targets. See the documentation of your specific tokenizer for more details
#   FutureWarning,
# Decoding outputs:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
df1 =  pd.DataFrame({'input': eval_df['input_text'], 'pred':sinhala_preds})

# %%
def smart(x):
  double_e = 'e'+'́'
  double_o = 'o' + '̂'
  double_o_dots = 'o' + '̈'
  y = x.replace(double_e, 'é').replace(double_o, 'ô').replace(double_o_dots, 'ö')
  y = y.replace('▁', ' ')
  y = y.replace('_', ' ')
  y = y.capitalize()
  return y

# %%
df1.pred = df1.pred.apply(smart)

# %%
# eval_df.to_csv('test.tsv', sep='\t', index=False, header=False)
df1.to_csv('seq_bnt.tsv', sep='\t', index=False, header=False)

# %%
df1.head()
# Out:
#                                                             input                                                                     pred
# 0                                                  Ti me bot yem.                                                         Ti mɛ̀ ɓɔ̀t yɛm.
# 1                               Mimaŋ mi bôdaa mi ŋaŋna ni jomol.                                       Mìmaŋ mi ɓodàa mi ŋāŋna ni jɔ̀mɔl.
# 2                      Me bibagla ni bôt bem, me bibagla bôt bem.                             Mɛ̀ biɓāgla ni ɓôt ɓɛm, mɛ̀ biɓāgla ɓôt ɓɛm.
# 3  Nu a ŋôm bés ni béé makôô isi siŋ siŋ i Kristô... (2kor.1,21).  Nù à ŋ̀om ɓes nì ɓèe makòò isı̄ sı sı sı i krı̌stò... (2krı̌stòr.1,21).
# 4                                         Me galo ga ha, ni tehe.                                               Mɛ̀ galɔ̀ ga hâ, ni tɛhɛ̀.

# %%
# !python3 evaluate.py corr_dev.tsv seq_bnt.tsv
# Out:
# CER: 24.0792404326368
# WER: 62.543060435360054
